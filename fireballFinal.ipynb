# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import datasets,linear_model
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import os
os.chdir("C:/Users/Intel/Desktop/ChasersOfLostData")

# %%
data=pd.read_csv("Fireball_And_Bolide_Reports.csv")

# %%
a=data._get_numeric_data()
print(type(a))
b=a.interpolate()
rs = np.random.RandomState(0)
df = b
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
b
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Altitude (km)  Velocity (km/s)  Velocity Components (km/s): vx  \
# 0       38.000000        32.100000                        3.000000
# 1       36.000000        26.800000                      -10.700000
# 2       44.000000        21.500000                       14.400000
# 3       22.200000        16.200000                       -2.300000
# 4       26.300000        16.372727                       11.500000
# 5       27.600000        16.545455                       -1.733333
# 6       28.900000        16.718182                      -14.966667
# 7       39.000000        16.890909                      -28.200000
# 8       39.000000        17.063636                      -12.950000
# 9       23.500000        17.236364                        2.300000
# 10      32.750000        17.409091                       -0.866667
# 11      42.000000        17.581818                       -4.033333
# ...

# %%
b = b.rename(columns = {"Calculated Total Impact Energy (kt)": "Energy"})

# %%
y=b[b.columns[-1]]
b=b.iloc[:,:-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(b, y, test_size=0.2)

# %%
lmm = linear_model.LinearRegression()
model=lmm.fit(X_train, y_train)
predictions = lmm.predict(X_test)

# %%
print ("Score: ", model.score(X_test, y_test))
# Out:
# Score:  0.8142242773049669

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
df
# Out:
#     Actual   Predicted
# 69    1.20    1.081758
# 57    0.23    0.156617
# 54    0.35    0.386808
# 68    0.36    0.456710
# 66    0.75    0.766559
# 90    0.27    0.548745
# 39    0.18    0.144445
# 86    0.12    0.199917
# 88    0.15    0.236242
# 48    0.10    0.304849
# 8     0.23    0.403940
# 7     0.11    0.468789
# 63    0.19    0.242013
# 23  440.00  624.109400
# 45    0.36    0.426631
# 18    0.41    0.533007
# 79    0.22    0.140318
# 0    18.00   16.439429
# 28    3.50    3.063311

# %%
X_train, X_test, y_train, y_test = train_test_split(b, y, test_size=0.2)
y_train = y_train.ravel()
y_test = y_test.ravel()
y
# Out:
# 0      18.000
# 1       0.410
# 2       0.820
# 3       7.600
# 4       0.110
# 5       0.230
# 6       0.120
# 7       0.110
# 8       0.230
# 9       0.200
# 10      0.120
# 11      0.190
# 12      0.450
# 13      0.073
# 14     33.000
# 15      0.400
# 16      6.900
# 17      0.120
# 18      0.410
# 19      0.430
# 20      0.320
# 21      1.300
# 22      0.290
# 23    440.000
# 24      0.130
# 25     33.000
# 26      0.670
# 27      0.120
# 28      3.500
# 29      0.230
#        ...
# 62      0.100
# 63      0.190
# 64      0.210
# 65      0.073
# 66      0.750
# 67      0.550
# 68      0.360
# 69      1.200
# 70      0.130
# 71      0.190
# 72      0.089
# 73      0.360
# 74      0.082
# 75      0.200
# 76      0.580
# 77      0.082
# 78      0.490
# 79      0.220
# 80      0.680
# 81      0.670
# 82      0.140
# 83      0.170
# 84      0.420
# 85      0.320
# 86      0.120
# 87      0.630
# 88      0.150
# 89      0.390
# 90      0.270
# 91      0.390
# ...
